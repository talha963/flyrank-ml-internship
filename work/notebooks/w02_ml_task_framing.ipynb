# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/talha963/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*
#
# Task Type: Classification
#
# I am treating this as a classification problem because the goal is to predict the trend category of a content opportunity (for example, up, down, stable, or new) using its features such as search volume, CPC, competition, and content intent.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
from datasets import load_dataset
import pandas as pd

dataset = load_dataset("FlyRank/internship-starter")

df = dataset["train"].to_pandas()

df["trend_direction"].value_counts()
# Out:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*
#
# Target: trend_direction
#
# This target represents the expected trend of each content opportunity. It is an observed label in the dataset and will be used as the prediction target.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
df["trend_direction"].head()
# Out:
# 0      down
# 1      down
# 2      down
# 3    stable
# 4      down
# Name: trend_direction, dtype: str

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*
#
# Success Metric: Macro F1 Score
#
# Because the target contains multiple classes with different frequencies, Macro F1 Score measures performance fairly across all classes.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
df["trend_direction"].value_counts(normalize=True)
# Out:
# trend_direction
# down      0.542067
# stable    0.198733
# up        0.146267
# new       0.074533
# flat      0.038400
# Name: proportion, dtype: float64

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*
#
# One row represents one content opportunity (one keyword or content idea). Each row contains features describing that content opportunity, including search volume, competition, CPC, intent, and other attributes.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print(df.head())

print(df.shape)
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... trend_pct health_score  needs_indexing  is_quick_win  \
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*
#
# A fixed rule such as "recommend all topics with search volume greater than 5000" ignores many other important signals like CPC, competition, content type, and user intent. Machine learning can learn complex relationships among multiple features and adapt as data changes, producing better recommendations than manually written rules.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
df[
    [
        "search_volume",
        "competition",
        "cpc",
        "main_intent",
        "trend_direction"
    ]
].head()
# Out:
#    search_volume  competition   cpc    main_intent trend_direction
# 0           10.0         0.67  2.05  transactional            down
# 1           90.0         0.01  0.05  informational            down
# 2            0.0         0.00  0.00  informational            down
# 3           10.0         0.00  0.00     commercial          stable
# 4            0.0         0.00  0.00  informational            down

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
